# %% [markdown]
# #Data Set
#
# ###The chosen data set revolves around the salaries of data scientists in various

# %%
filepath = '/content/ds_salaries.csv'

# %%
import pandas as pd
import numpy as np
import statistics

# %% [markdown]
# #Original Data Set

# %%
data = pd.read_csv(filepath)
data
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
column_names = data.columns
print(column_names)
# Out:
# Index(['id', 'work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
data_types = data.dtypes
print(data_types)
# Out:
# id                     int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
total_records = data.shape
rows = data.shape[0]
columns = data.shape[1]
print("Total: ", total_records)
print("Rows: ", rows)
print("Columns: ", columns)
# Out:
# Total:  (607, 12)
# Rows:  607
# Columns:  12

# %%
data.describe()
# Out:
#                id    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %% [markdown]
# #Excluding columns that do not affect salary

# %%
df = pd.read_csv(filepath, index_col = 'id')
df.drop([ 'salary', 'salary_currency', 'employee_residence'], axis = 1, inplace = True)
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# id
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %% [markdown]
# #Number of employees per experience level
# #### EN = Entry Level
# #### MI = Mid Level
# #### SE = Senior Level
# #### EX = Executive Level

# %%
df = pd.read_csv(filepath, index_col = 'experience_level')
df.drop([ 'salary', 'salary_currency', 'employee_residence'], axis = 1, inplace = True)
df.sort_values("experience_level")
# Out:
#                    id  work_year employment_type                   job_title  \
# experience_level
# EN                113       2021              PT                AI Scientist
# EN                139       2021              FT              Data Scientist
# EN                134       2021              FT              Data Scientist
# EN                131       2021              FT              Data Scientist
# EN                130       2021              FT  Machine Learning Developer
# ...               ...        ...             ...                         ...
# SE                364       2022              FT               Data Engineer
# SE                363       2022              FT                Data Analyst
# SE                362       2022              FT                Data Analyst
# SE                371       2022              FT   Machine Learning Engineer
# SE                303       2022              FT              Data Scientist
#
# ...

# %% [markdown]
# #Employees based on Job Title
# There are 50 unique job titles

# %%
df = pd.read_csv(filepath, index_col = 'job_title')
df.drop([ 'salary', 'salary_currency', 'employee_residence'], axis = 1, inplace = True)
df.sort_values("job_title")
# Out:
#                                 id  work_year experience_level  \
# job_title
# 3D Computer Vision Researcher   77       2021               MI
# AI Scientist                   606       2022               MI
# AI Scientist                    96       2021               EN
# AI Scientist                   113       2021               EN
# AI Scientist                   244       2021               EN
# ...                            ...        ...              ...
# Research Scientist             508       2022               EN
# Research Scientist             507       2022               MI
# Research Scientist              26       2020               EN
# Research Scientist             236       2021               MI
# Staff Data Scientist           283       2021               SE
#
#                               employment_type  salary_in_usd  remote_ratio  \
# job_title
# 3D Computer Vision Researcher              PT           5409            50
# ...

# %% [markdown]
# #Employees based on employment type

# %%
employment_type = pd.DataFrame(df)
employment_type = df[df['employment_type'] == 'CT'].copy()
employment_type # This results into 5 employees with CT
# Out:
#                    id  work_year employment_type  \
# experience_level
# EN                 28       2020              CT
# MI                 78       2021              CT
# EX                225       2021              CT
# SE                283       2021              CT
# EN                489       2022              CT
#
#                                            job_title  salary salary_currency  \
# experience_level
# EN                             Business Data Analyst  100000             USD
# MI                                       ML Engineer  270000             USD
# EX                          Principal Data Scientist  416000             USD
# SE                              Staff Data Scientist  105000             USD
# EN                Applied Machine Learning Scientist   29000             EUR
#
#                   salary_in_usd employee_residence  remote_ratio  \
# experience_level
# EN                       100000                 US           100
# ...

# %%
employment_type = df[df['employment_type'] == 'PT'].copy()
employment_type # This results into 10 employees with Part Time Employment Type
# Out:
#                    id  work_year employment_type  \
# experience_level
# EN                 45       2020              PT
# EN                 62       2020              PT
# MI                 77       2021              PT
# EN                 96       2021              PT
# EN                113       2021              PT
# EN                124       2021              PT
# EN                216       2021              PT
# MI                282       2021              PT
# MI                462       2022              PT
# EN                487       2022              PT
#
#                                       job_title  salary salary_currency  \
# experience_level
# EN                                  ML Engineer   14000             EUR
# EN                               Data Scientist   19000             EUR
# MI                3D Computer Vision Researcher  400000             INR
# EN                                 AI Scientist   12000             USD
# ...

# %%
employment_type = df[df['employment_type'] == 'FT'].copy()
employment_type # This results into 591 Full-Time employees
# Out:
#                    id  work_year employment_type                   job_title  \
# experience_level
# MI                  0       2020              FT              Data Scientist
# SE                  1       2020              FT  Machine Learning Scientist
# SE                  2       2020              FT           Big Data Engineer
# MI                  3       2020              FT        Product Data Analyst
# SE                  4       2020              FT   Machine Learning Engineer
# ...               ...        ...             ...                         ...
# SE                602       2022              FT               Data Engineer
# SE                603       2022              FT               Data Engineer
# SE                604       2022              FT                Data Analyst
# SE                605       2022              FT                Data Analyst
# MI                606       2022              FT                AI Scientist
#
# ...
